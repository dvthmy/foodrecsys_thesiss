# %%
import pandas as pd

# %%
df = pd.read_csv('../user.csv')
df.head()
# Out:
#          Dấu thời gian Giới tính (Gender)          Độ tuổi (Age)    \
# 0  03/10/2025 21:34:22          Nam (Male)  18 – 24 tuổi (18 – 24)
# 1  03/10/2025 23:30:38          Nam (Male)  25 – 34 tuổi (25 – 34)
# 2   04/10/2025 0:00:53         Nữ (Female)  18 – 30 tuổi (18 – 30)
# 3   04/10/2025 0:05:58          Nam (Male)  30 – 34 tuổi (30 – 34)
# 4   04/10/2025 0:05:59         Nữ (Female)  18 – 30 tuổi (18 – 30)
#
#     Bạn có hạn chế chế độ ăn nào không? (Do you have any dietary restrictions?)    \
# 0                                Dị ứng (Allergies )
# 1                               Ít đường (Low sugar)
# 2                 Không có hạn chế (No restrictions)
# 3                 Không có hạn chế (No restrictions)
# 4                                Dị ứng (Allergies )
#
#     Bạn có dị ứng với thực phẩm nào không? (Do you have any food allergies?)    \
# 0                                  Hải sản (Seafood)
# 1                        Không dị ứng (No allergies)
# ...
